# %% [markdown]
# # Real-data spike-count comparison
#
# This notebook compares the spike-number estimation of different methods to reproduce Table 2.

# %%
import importlib
import real_data as comparison

comparison = importlib.reload(comparison)

# %% [markdown]
# ## Run the comparison

# %%
results, comparison_wide = comparison.main()
display(comparison_wide)
# Out:
# GEUVADIS: loaded data/GEUVADIS_matrix.npy exactly as stored; shape n x p = (400, 200)
# 1000G_EUR: loaded data/1000G_EUR_matrix.npy exactly as stored; shape n x p = (400, 1500)
# Running: GEUVADIS
# Running: 1000G_EUR
# dataset   1000G_EUR  GEUVADIS
# method
# Proposed          4         4
# BA2017          288        31
# FGZ2022           3         4
# KML2023           3         4
# BN2002            0         3
# DO2019            3         4
# Onat2009          0         0
# DY2022            1         2
# PY2014            2         4
